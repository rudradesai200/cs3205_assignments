# %%
import matplotlib.pyplot as plt
import cv2

# %%
fig=plt.figure(figsize=(100, 100))
columns = 3
rows = 3
for i in range(1, columns*rows):
    img = cv2.imread(f'output{i}.png')
    fig.add_subplot(rows, columns, i)
    plt.axis('off')
    plt.title(f'Router {i+1}',fontsize=70)
    plt.imshow(img)
plt.savefig('check.png')

# %%
fig.show()
# Out:
# /home/rudra/miniconda3/envs/ml/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """Entry point for launching an IPython kernel.
